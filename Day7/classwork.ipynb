# %%
content=open('a.txt','r')

# %%
#content.read()
content.readline()
# Out:
# '102,Priya,22,90\n'

# %%
content.seek(0) # we cannnot provide negtive indexes 
content.readline()
# Out:
# '101,Rahul,21,85\n'

# %%
content.readlines()
# Out:
# ['102,Priya,22,90\n',
#  '103,Amit,20,78\n',
#  '104,Sneha,23,88\n',
#  '105,Vikram,21,92\n',
#  '106,Anjali,22,81\n',
#  '107,Rohit,20,75\n',
#  '108,Pooja,23,89\n',
#  '109,Arjun,21,84\n',
#  '110,Neha,22,87']

# %%
content.close()

# %%
f=open("a.txt","w")
f.write("Hello")
# Out:
# 5

# %%
# to write multiple line in the file
f.write('''hello my name
        is rishu
        kumar
        where are you
        from''')
f.close()

# %%
f=open("data.txt","w")
f.writelines(["Hello\n","My name is\n","Rishu"])
f.close()

# %%
with open("a.txt","w") as f:
    f.writelines('''my name" \n 
    "is rishu kumar" \n
    "where is your home" \n
    "tell me now"\n
    "otherwise''')

# %%
with open("a.txt","r+") as f:
    f.write("Hit")

# %%
with open("data.txt") as f:
    print(len(f.read().split()))
# Out:
# 1

# %%
with open("data.txt") as f:
    print(len(set(f.read().split())))
# Out:
# 5

# %%
with open("data.txt") as f:
    lst=f.read().split()
    dis={}
    for str in lst:
        if str in dis:
            dis[str]+=1
        else:
            dis[str]=1
print(dis)
# Out:
# {'Technology': 2, 'is': 1, 'growing': 1, 'rapidly': 1, 'in': 1, 'todayâ€™s': 1, 'world.': 1, 'It': 1, 'has': 1, 'changed': 1, 'the': 1, 'way': 1, 'people': 1, 'communicate,': 1, 'learn,': 1, 'and': 1, 'work.': 1, 'Almost': 1, 'every': 1, 'industry': 1, 'now': 1, 'depends': 1, 'on': 1, 'digital': 1, 'tools': 1}

# %%
data={
    "name":"Rishu"
    ,"age":21,
    "course":"CSE"
}

# %%
import json

data = {
    "id": 1,
    "name": "Rishu",
    "course": "Data Science"
}

# Write JSON
with open("json1.json", "w") as f:
    json.dump(data, f)

# Read JSON
with open("json1.json", "r") as f:
    da = json.load(f)
    print(da)
# Out:
# {'id': 1, 'name': 'Rishu', 'course': 'Data Science'}

# %%
import csv
with open("data.csv","w",newline="") as file:
    writer=csv.writer(file)
    writer.writerow(["Name","Age","Course"])
    writer.writerow(["Rishu",21,"CSE"])

# %%
rows=[
    ["Name","Age"],
    ["Piyush",21],
    ["Sunny",22]
]

with open("data.csv","w",newline="") as file:
    writer=csv.writer(file)
    writer.writerows(rows)

# %%
import csv

with open("data.csv", "w", newline="") as file:
    fieldnames = ["Name", "Age"]
    
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    
    writer.writeheader()
    
    writer.writerow({"Name": "Aditya", "Age": 22})
    writer.writerow({"Name": "Riya", "Age": 21})
    writer.writerow({"Name": "Rahul", "Age": 23})

print("CSV file written successfully!")
# Out:
# CSV file written successfully!

# %%
with open("data.csv","r") as file:
    reader=csv.DictReader(file)
    print(reader)
    for row in reader:
        print(row)
# Out:
# ...
# {'Name': 'Aditya', 'Age': '22'}
# {'Name': 'Riya', 'Age': '21'}
# {'Name': 'Rahul', 'Age': '23'}
