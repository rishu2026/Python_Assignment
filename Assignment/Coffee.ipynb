# %%
import pandas as pd
import numpy as np


df = pd.read_csv("Coffee.csv")

df.head()
# Out:
#    Unnamed: 0  Year    Country  Domestic Consumption  Exports  Import Price  \
# 0           0  2015  Argentina               13051.0  14887.0           2.6
# 1           1  2015  Argentina               13131.0  15055.0           2.6
# 2           2  2015  Argentina               13305.0  15075.0           2.7
# 3           3  2015     Brazil               21070.0  36806.0           1.9
# 4           4  2015     Canada               18063.0  21734.0           3.9
#
#    Export Price  Total Production
# 0           2.7           26614.0
# 1           3.0           27019.0
# 2           NaN           27232.0
# 3           1.9           54721.0
# 4           4.0           38987.0

# %% [markdown]
# 1) Rows and Columns

# %%
df.shape
# Out:
# (520, 8)

# %% [markdown]
# 2) Column Names

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Country', 'Domestic Consumption', 'Exports',
#        'Import Price', 'Export Price', 'Total Production'],
#       dtype='str')

# %% [markdown]
# 3) Data Type of Each Column

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# Year                      int64
# Country                     str
# Domestic Consumption    float64
# Exports                 float64
# Import Price            float64
# Export Price            float64
# Total Production        float64
# dtype: object

# %% [markdown]
# 4) First 5 Rows

# %%
df.head()
# Out:
#    Unnamed: 0  Year    Country  Domestic Consumption  Exports  Import Price  \
# 0           0  2015  Argentina               13051.0  14887.0           2.6
# 1           1  2015  Argentina               13131.0  15055.0           2.6
# 2           2  2015  Argentina               13305.0  15075.0           2.7
# 3           3  2015     Brazil               21070.0  36806.0           1.9
# 4           4  2015     Canada               18063.0  21734.0           3.9
#
#    Export Price  Total Production
# 0           2.7           26614.0
# 1           3.0           27019.0
# 2           NaN           27232.0
# 3           1.9           54721.0
# 4           4.0           38987.0

# %% [markdown]
# 5) Last 5 Rows

# %%
df.tail()
# Out:
#      Unnamed: 0  Year  Country  Domestic Consumption  Exports  Import Price  \
# 515         515  2023      USA               28629.0      0.0           5.3
# 516         516  2023      USA               28875.0      0.0           5.2
# 517         517  2023  Vietnam                   NaN  34342.0           2.9
# 518         518  2023  Vietnam               18557.0  34695.0           3.2
# 519         519  2023  Vietnam               18615.0  34840.0           3.0
#
#      Export Price  Total Production
# 515           0.0               0.0
# 516           0.0               0.0
# 517           3.2           52222.0
# 518           2.9           52867.0
# 519           NaN           52639.0

# %% [markdown]
# 6) Columns with Missing Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Year                     0
# Country                  0
# Domestic Consumption    26
# Exports                 26
# Import Price            26
# Export Price            26
# Total Production        26
# dtype: int64

# %% [markdown]
# 7) Unique Countries Count

# %%
df["Country"].nunique()
# Out:
# 20

# %% [markdown]
# 8) Records Per Year

# %%
df["Year"].value_counts().sort_index()
# Out:
# Year
# 2015    73
# 2016    58
# 2017    59
# 2018    44
# 2019    57
# 2020    58
# 2021    61
# 2022    56
# 2023    54
# Name: count, dtype: int64

# %% [markdown]
# 10) Min, Max, Avg of Total Production

# %%
df["Country"].value_counts()
# Out:
# Country
# France          31
# Argentina       30
# Colombia        30
# Chile           29
# South Africa    29
# Germany         28
# Italy           28
# Mexico          28
# Indonesia       27
# China           26
# India           26
# USA             25
# Canada          24
# Turkey          24
# Vietnam         24
# Brazil          23
# Ethiopia        23
# Kenya           23
# Thailand        22
# Peru            20
# Name: count, dtype: int64

# %% [markdown]
# 10) Min, Max, Avg of Total Production

# %%
df["Total Production"].min(), \
df["Total Production"].max(), \
df["Total Production"].mean()
# Out:
# (np.float64(0.0), np.float64(264565.0), np.float64(46466.72672064777))

# %% [markdown]
# 11) Country with Highest Total Production (Single Record)

# %%
df.loc[df["Total Production"].idxmax()]
# Out:
# Unnamed: 0                   480
# Year                        2023
# Country                    China
# Domestic Consumption    159839.0
# Exports                 108888.0
# Import Price                 3.9
# Export Price                 3.8
# Total Production        264565.0
# Name: 480, dtype: object

# %% [markdown]
# 12) Rows Where Production is Missing or Zero

# %%
df[(df["Total Production"].isnull()) | (df["Total Production"] == 0)]
# Out:
#      Unnamed: 0  Year  Country  Domestic Consumption  Exports  Import Price  \
# 14           14  2015    China              119776.0  85031.0           3.0
# 27           27  2015  Germany                8514.0  11030.0           3.2
# 28           28  2015  Germany                8514.0  11030.0           3.2
# 29           29  2015  Germany                8887.0  11273.0           3.4
# 30           30  2015  Germany                8396.0  10988.0           3.0
# ..          ...   ...      ...                   ...      ...           ...
# 512         512  2023      USA               28601.0      0.0           5.5
# 513         513  2023      USA               28632.0      0.0           5.1
# 514         514  2023      USA               29342.0      0.0           5.5
# 515         515  2023      USA               28629.0      0.0           5.3
# 516         516  2023      USA               28875.0      0.0           5.2
#
#      Export Price  Total Production
# ...

# %% [markdown]
# 13) Average Import Price

# %%
df["Import Price"].mean()
# Out:
# np.float64(3.1564777327935225)

# %% [markdown]
# 14) Total Coffee Production Per Year

# %%
df.groupby("Year")["Total Production"].sum()
# Out:
# Year
# 2015    2551154.0
# 2016    2163533.0
# 2017    2438153.0
# 2018    1793354.0
# 2019    2593378.0
# 2020    2756933.0
# 2021    2867085.0
# 2022    2681517.0
# 2023    3109456.0
# Name: Total Production, dtype: float64

# %% [markdown]
# 15) Top 5 Countries by Total Production

# %%
df.groupby("Country")["Total Production"].sum().sort_values(ascending=False).head(5)
# Out:
# Country
# China        5682192.0
# India        1902283.0
# Mexico       1838210.0
# France       1837554.0
# Indonesia    1582361.0
# Name: Total Production, dtype: float64

# %% [markdown]
# 16) Country with Highest Average Export Price

# %%
df.groupby("Country")["Export Price"].mean().sort_values(ascending=False).head(1)
# Out:
# Country
# Canada    4.338095
# Name: Export Price, dtype: float64

# %% [markdown]
# 17) Domestic Consumption > Total Production?

# %%
df[df["Domestic Consumption"] > df["Total Production"]]
# Out:
#      Unnamed: 0  Year  Country  Domestic Consumption  Exports  Import Price  \
# 27           27  2015  Germany                8514.0  11030.0           3.2
# 28           28  2015  Germany                8514.0  11030.0           3.2
# 29           29  2015  Germany                8887.0  11273.0           3.4
# 30           30  2015  Germany                8396.0  10988.0           3.0
# 32           32  2015  Germany                8121.0  11043.0           3.1
# 63           63  2015      USA               24902.0      NaN           4.6
# 64           64  2015      USA               25244.0      0.0           4.4
# 66           66  2015      USA               24831.0      0.0           4.2
# 94           94  2016  Germany                8792.0  11048.0           3.3
# 95           95  2016  Germany                8670.0  10868.0           3.2
# 96           96  2016  Germany                8369.0  11295.0           3.0
# ...

# %% [markdown]
# 18) Country with Highest Production Growth

# %%
growth = df.groupby("Country")["Total Production"].apply(lambda x: x.max() - x.min())
growth.sort_values(ascending=False).head(1)
# Out:
# Country
# China    64784.0
# Name: Total Production, dtype: float64

# %% [markdown]
# 19) Relationship Between Export Price & Total Production

# %%
df["Export Price"].corr(df["Total Production"])
# Out:
# np.float64(0.34420346614210934)

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Export Price"], df["Total Production"])
plt.xlabel("Export Price")
plt.ylabel("Total Production")
plt.title("Export Price vs Total Production")
plt.show()

# %% [markdown]
# Summary

# %%
'''1. The dataset contains coffee production data across multiple countries and years.
2. Production varies significantly across countries, with a few countries dominating total output.
3. Export and import prices show moderate variation over time.
4. Some countries show steady growth in production over the years.
5. There appears to be a weak/moderate correlation between export price and total production.'''
