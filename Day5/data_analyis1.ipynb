# %%
import pandas as pd
s=pd.Series([10,20,30,10],index=[10,11,12,13])
#we can directly pass the index in series as per our need
#also we can pass index with the help of dictionary
q=pd.Series({'a':1,"b":2})
print(s.values)
s.index

#to check size of series
q.size
#to calculate mean
print(s.mean())

#to calculate max
s.max()

#to calculate min
s.min()

#to calculate standard deviation
s.std()

#to sum alll values
s.sum()

#to count the frequency
s.value_counts()
# Out:
# [10 20 30 10]
# 17.5
# 10    2
# 20    1
# 30    1
# Name: count, dtype: int64

# %%
#collection of series is termed as  dataframe

a=pd.DataFrame([1,2],[3,4])
type(a)
# Out:
# pandas.DataFrame

# %%
pd.DataFrame({'A':[1,2],'B':[3,4]})
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
#Load data
df=pd.read_csv('WineQT.csv')
#to get data from staring
df.head()
#to get data from end
df.tail(3)

#to get random record
df.sample(5, ignore_index=True)

#To check dimension of the dataframe
df.ndim

#to check size of data
df.size

#To get column name
df.columns

#To get basic info of data
df.info()

#to get description of the data
df.describe(include="all")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB
# ...

# %%
df.describe(include='int')
# Out:
#            quality           Id
# count  1143.000000  1143.000000
# mean      5.657043   804.969379
# std       0.805824   463.997116
# min       3.000000     0.000000
# 25%       5.000000   411.000000
# 50%       6.000000   794.000000
# 75%       6.000000  1209.500000
# max       8.000000  1597.000000

# %%
# Data Types Handling
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.alcohol.dtype

df['fixed acidity'].dtype

#to select the data that is of only integer datatype
df.select_dtypes(include='int').columns

#indexing and selection

df.iloc[0:2,0:4]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar
# 0            7.4              0.70          0.0             1.9
# 1            7.8              0.88          0.0             2.6

# %%
df['fixed acidity'][0]

df.iat[0,1]
# Out:
# np.float64(0.7)

# %%
#misssing value
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# fixed acidity           1143
# volatile acidity        1143
# citric acid             1143
# residual sugar          1143
# chlorides               1143
# free sulfur dioxide     1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
#to drop null data
df.dropna

#to fill null value
df.fillna(0)

#Duplicated data
df.duplicated().sum() 

#remove duplicate data
df.drop_duplicates(inplace=True)

#another way
df=df.drop_duplicates()

#to sort values
df.sort_values(by='alcohol')

df.sample(5,ignore_index=True).sort_index(ascending=False)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4            6.1              0.32         0.25             1.8      0.086
# 3            7.9              0.34         0.42             2.0      0.086
# 2            7.2              0.66         0.03             2.3      0.078
# 1           11.2              0.67         0.55             2.3      0.084
# 0            7.8              0.48         0.68             1.7      0.415
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                  5.0                  32.0  0.99464  3.36       0.44
# 3                  8.0                  19.0  0.99546  3.35       0.60
# 2                 16.0                  86.0  0.99743  3.53       0.57
# 1                  6.0                  13.0  1.00000  3.17       0.71
# 0                 14.0                  32.0  0.99656  3.09       1.06
#
#    alcohol  quality    Id
# 4     10.1        5  1355
# 3     11.4        6  1091
# ...

# %%
df.sample(5).reset_index(drop=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           12.0              0.37         0.76             4.2      0.066
# 1            8.0              0.50         0.39             2.6      0.082
# 2           10.3              0.50         0.42             2.0      0.069
# 3           10.0              0.59         0.31             2.2      0.090
# 4            9.2              0.46         0.23             2.6      0.091
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  7.0                  38.0  1.00040  3.22       0.60
# 1                 12.0                  46.0  0.99850  3.43       0.62
# 2                 21.0                  51.0  0.99820  3.16       0.72
# 3                 26.0                  62.0  0.99940  3.18       0.63
# 4                 18.0                  77.0  0.99922  3.15       0.51
#
#    alcohol  quality    Id
# 0     13.0        7   395
# 1     10.7        6  1404
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
df.quality.unique()

df['fixed acidity'].unique()

df.quality.value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
df[df['quality'] > 5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 12              8.5              0.28         0.56             1.8      0.092
# 13              7.9              0.32         0.51             1.8      0.341
# ...             ...               ...          ...             ...        ...
# 1136            6.3              0.55         0.15             1.8      0.077
# 1137            5.4              0.74         0.09             1.7      0.089
# 1138            6.3              0.51         0.13             2.3      0.076
# 1139            6.8              0.62         0.08             1.9      0.068
# 1141            5.9              0.55         0.10             2.2      0.062
#
# ...

# %%
df.alcohol*=2
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
def rating(quality):
    if quality>5:
        return "Good"
    else:
        return "Bad"


df['quality review']=df['quality'].apply(rating)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id quality review
# 0     18.8        5   0            Bad
# ...

# %%
df['quality_label']=df['quality'].map({3:'Very Bad',
                                       4:'Bad'
                                       ,5:'Good'
                                       ,6:"Very Good"
                                       ,7:"Nice"
                                       ,8:"Excellent"})

df['quality_label2']=df['quality_label'].map({
    "Good":'Good1',"Bad":"Bad2"
})
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df['quality_replace']=df['quality_label'].replace({
    "Good":"Good1","Bad":"Bad1"
})

df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df.rename(columns={"fixed acidity": "ACIDITY"}, inplace=True)
df.head()
# Out:
#    ACIDITY  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      7.4              0.70         0.00             1.9      0.076
# 1      7.8              0.88         0.00             2.6      0.098
# 2      7.8              0.76         0.04             2.3      0.092
# 3     11.2              0.28         0.56             1.9      0.075
# 4      7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id quality review quality_label quality_label2  \
# ...

# %%
df.to_csv("Wine_updated.csv",index=False)

# %% [markdown]
# #String Operation

# %%
df1=pd.read_csv("wine_data.csv")
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.50              0.28         0.56             1.8      0.092
# 1           8.00              0.59         0.16             1.8      0.065
# 2           9.60              0.32         0.47             1.4      0.056
# 3          12.80              0.30         0.74             2.6      0.095
# 4           9.91              0.45         0.49             2.8      0.053
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 35.0                 103.0  0.99690  3.30       0.75
# 1                  3.0                  16.0  0.99620  3.42       0.92
# 2                  9.0                  24.0  0.99695  3.22       0.82
# 3                  9.0                  28.0  0.99940  3.20       0.77
# 4                 21.9                  60.5  0.99683  3.31       0.90
#
#    alcohol  quality   Id                       name        date
# ...

# %%
df1.name.str.upper()
# Out:
# 0                                WINEA
# 1                                WINEB
# 2                                WINEC
# 3                                WINED
# 4            WEINGUT SYRAH RESERVE 575
#                     ...
# 215           BODEGA PINOT CLASSIC 513
# 216       CASTELLO MERLOT GRAND CRU 41
# 217    BODEGA CHARDONNAY GRAND CRU 257
# 218       CHATEAU CABERNET SPECIAL 857
# 219       BODEGA SAUVIGNON CLASSIC 591
# Name: name, Length: 220, dtype: str

# %%
df1.name.str.capitalize()
df1.name.str.len()
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4      25
#        ..
# 215    24
# 216    28
# 217    31
# 218    28
# 219    28
# Name: name, Length: 220, dtype: int64

# %%
df1[df1.name.str.contains("a")]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4             9.91              0.45         0.49             2.8      0.053
# 5             8.72              0.56         0.34             0.8      0.059
# 6             9.54              0.61         0.41             3.1      0.064
# 7             9.08              0.63         0.49             1.1      0.072
# 8             8.88              0.44         0.40             2.9      0.079
# ..             ...               ...          ...             ...        ...
# 215          10.62              0.38         0.41             3.0      0.072
# 216          10.21              0.17         0.60             2.5      0.059
# 217          11.29              0.36         0.46             2.8      0.082
# 218           9.21              0.36         0.51             2.6      0.082
# 219          10.02              0.21         0.47             1.8      0.050
#
# ...

# %%
df1['date']=pd.to_datetime(df1.date)
df1['Year']=df1.date.dt.year
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         220 non-null    float64
#  1   volatile acidity      220 non-null    float64
#  2   citric acid           220 non-null    float64
#  3   residual sugar        220 non-null    float64
#  4   chlorides             220 non-null    float64
#  5   free sulfur dioxide   220 non-null    float64
#  6   total sulfur dioxide  220 non-null    float64
#  7   density               220 non-null    float64
#  8   pH                    220 non-null    float64
#  9   sulphates             220 non-null    float64
#  10  alcohol               220 non-null    float64
#  11  quality               220 non-null    int64
#  12  Id                    220 non-null    int64
#  13  name                  220 non-null    str
#  14  date                  220 non-null    datetime64[us]
# ...

# %%
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.50              0.28         0.56             1.8      0.092
# 1           8.00              0.59         0.16             1.8      0.065
# 2           9.60              0.32         0.47             1.4      0.056
# 3          12.80              0.30         0.74             2.6      0.095
# 4           9.91              0.45         0.49             2.8      0.053
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 35.0                 103.0  0.99690  3.30       0.75
# 1                  3.0                  16.0  0.99620  3.42       0.92
# 2                  9.0                  24.0  0.99695  3.22       0.82
# 3                  9.0                  28.0  0.99940  3.20       0.77
# 4                 21.9                  60.5  0.99683  3.31       0.90
#
#    alcohol  quality   Id
# 0    10.50        7   16
# 1    10.50        7  128
# ...

# %%
df1['High_Alcohol']=df1.alcohol >=10
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.50              0.28         0.56             1.8      0.092
# 1           8.00              0.59         0.16             1.8      0.065
# 2           9.60              0.32         0.47             1.4      0.056
# 3          12.80              0.30         0.74             2.6      0.095
# 4           9.91              0.45         0.49             2.8      0.053
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 35.0                 103.0  0.99690  3.30       0.75
# 1                  3.0                  16.0  0.99620  3.42       0.92
# 2                  9.0                  24.0  0.99695  3.22       0.82
# 3                  9.0                  28.0  0.99940  3.20       0.77
# 4                 21.9                  60.5  0.99683  3.31       0.90
#
#    alcohol  quality   Id  High_Alcohol
# 0    10.50        7   16          True
# ...

# %%
df1['Wine Type']='Red Wine'
df1.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           8.50              0.28         0.56             1.8      0.092
# 1           8.00              0.59         0.16             1.8      0.065
# 2           9.60              0.32         0.47             1.4      0.056
# 3          12.80              0.30         0.74             2.6      0.095
# 4           9.91              0.45         0.49             2.8      0.053
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 35.0                 103.0  0.99690  3.30       0.75
# 1                  3.0                  16.0  0.99620  3.42       0.92
# 2                  9.0                  24.0  0.99695  3.22       0.82
# 3                  9.0                  28.0  0.99940  3.20       0.77
# 4                 21.9                  60.5  0.99683  3.31       0.90
#
#    alcohol  quality   Id  High_Alcohol Wine Type
# ...

# %%
import pandas as pd

data1 = {
    'Name':['A','B','C'],
    'age':[23,24,27],
    'salary':[3000,4000,5000]
}

data2 = {
    'Name': ['A','E','C'],
    'age': [23,32,27],
    'salary': [3000,7000,5000]
}

new_df1 = pd.DataFrame(data1)
new_df2 = pd.DataFrame(data2)

print(new_df1)
print(new_df2)
# Out:
#   Name  age  salary
# 0    A   23    3000
# 1    B   24    4000
# 2    C   27    5000
#   Name  age  salary
# 0    A   23    3000
# 1    E   32    7000
# 2    C   27    5000

# %%
pd.concat([new_df1,new_df2],ignore_index=True,axis=1)
# Out:
#    0   1     2  3   4     5
# 0  A  23  3000  A  23  3000
# 1  B  24  4000  E  32  7000
# 2  C  27  5000  C  27  5000

# %%
#Merge

pd.merge(new_df1,new_df2,on='age',how='outer')
# Out:
#   Name_x  age  salary_x Name_y  salary_y
# 0      A   23    3000.0      A    3000.0
# 1      B   24    4000.0    NaN       NaN
# 2      C   27    5000.0      C    5000.0
# 3    NaN   32       NaN      E    7000.0
